# %%
import pandas as pd

df = pd.read_csv("https://www.irs.gov/pub/irs-soi/eo_nj.csv")
df.head(20)
# Out:
#          EIN                                               NAME  \
# 0    2030711       CHURCH OF OUR LORD JESUS CHRIST OF MACEDONIA
# 1    7764840  TRI-COUNTY LIGHTHOUSE BAPTIST CHURCH & MINISTR...
# 2   10015091                            HANOVER SOCCER CLUB INC
# 3   10360402  AMERICAN ASSOCIATION OF HEALTHCARE ADMINISTRAT...
# 4   10433461            MEDICAL DOSIMETRIST CERTIFICATION BOARD
# 5   10446520                                             MEMGMA
# 6   10485964         JANET H AND C HARRY KNOWLES FOUNDATION INC
# 7   10494871        NORTHEAST AGRICULTURAL-AVIATION ASSOCIATION
# 8   10505213                   TRUSTEES OF PRINCETON UNIVERSITY
# 9   10546456                           GREEN HORIZON FOUNDATION
# 10  10548602                      SHEPHERDS WALK FOUNDATION INC
# 11  10549394               FRIENDSHIP FAMILY WORSHIP CENTER INC
# 12  10551182                                   CENTER HEART INC
# 13  10552945                            HEARTFELT RESOURCES INC
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of              EIN                                               NAME  \
# 0        2030711       CHURCH OF OUR LORD JESUS CHRIST OF MACEDONIA
# 1        7764840  TRI-COUNTY LIGHTHOUSE BAPTIST CHURCH & MINISTR...
# 2       10015091                            HANOVER SOCCER CLUB INC
# 3       10360402  AMERICAN ASSOCIATION OF HEALTHCARE ADMINISTRAT...
# 4       10433461            MEDICAL DOSIMETRIST CERTIFICATION BOARD
# ...          ...                                                ...
# 51531  995134193                          CARING HANDS FUND USA INC
# 51532  995135522  CNHS GIRLS SOCCER BACK OF THE NET BOOSTER CLUB...
# 51533  995140603                                   KOEI KAN CLIFTON
# 51534  996006085              AMERICAN ACADEMY OF FAMILY PHYSICIANS
# 51535  996078202         JOSEPH CAMPBELL FOUNDATION ENDOWMENT TRUST
#
#                    ICO                STREET          CITY STATE         ZIP  \
# ...
